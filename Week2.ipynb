# %% [markdown]
# <a href="https://colab.research.google.com/github/khoirulwhyd/PCVK_Genap_2022/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# Accessing My Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PCVK_2022/images/gusdur.jpg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK_2022/images/gusdur.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

#simpan file image
#tampilkan plot dengan ukuran canvas yang lebih besar
fig = plt.figure(figsize=(10,10)) #ubah-ubah ukuran (10,10) sesuai kebutuan
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
#perhatikan koordinat titik titik pt1 dan pt2
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2)) #nilai 2 untuk menunjukkan bahwa tiap titk dibuat 2 channel yang mewakili R,G, dan B
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# PERTANYAAN
#
# **1. Apakah perbedaan gambar yang ditampilkan tanpa dan dengan matplotlib**
# Jawab : Gambar nya tidak akan keluar jika tidak menggunakan matplotlib
#
# **2. Apakah perbedaan dan pengaruhnya pembuatan black image antara tipe data int16 dan int32?**
#
# Jawab : Kalau int16 memiliki 16 gradasi warna dan kalau int32 memiliki 32 gradasi warna
#
# **3. Jelaskan tentang angka – angka yang terdapat pada reshape((-1,1,2))**
#
# Jawab : Reshape digunakan untuk mengubah baris kolom, nilai 1 untuk pemberian jarak antara baris, angka 2 untuk setiap barisnya terdapat 2 nilai array, dan angka -1 untuk jarak setiap nilai arraynya
#
# **4. Apakah kegunaan “google.colab.patches import cv2_imshow” pada potongan kode berikut : Screenshot 2022-02-26 111556.png**
#
# Jawab : Khusus penggunaan OpenCV di Google Colab, terdapat satu fungsi yang memerlukan patch atau perbaikan, yaitu c2.imshow(). Fungsinya untuk menampilkan gambar pada OpenCV
#
# **5. Apakah kegunaan “skimage import io” pada potongan kode soal nomer 4**
#
#   Jawab : Gambar skimage disimpan sebagai array Numpy 3 dimensi. Dalam gambar skimage, saluran merah ditentukan terlebih dahulu, lalu hijau, biru yaitu RGB. Gambar dibaca dari dsik dengan skimage io

# %% [markdown]
# **TUGAS**
# 1. Tampilkan image dalam channel Red-Green dan Green-Blue saja!

# %%
#TUGAS 


#RED-GREEN
img3 =  cv.imread('/content/drive/MyDrive/PCVK_2022/images/gusdur.jpg')
img3 = cv.imread('/content/drive/MyDrive/PCVK_2022/images/gusdur.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img3, cmap='RdYlGn')

# %% [markdown]
# **RED-BLUE**

# %%
#RED-BLUE
img3 =  cv.imread('/content/drive/MyDrive/PCVK_2022/images/gusdur.jpg')
img3 = cv.imread('/content/drive/MyDrive/PCVK_2022/images/gusdur.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img3, cmap='GnBu')

# %% [markdown]
# 2. Tampilkan image baris ke 10-100, kolom 10-100!

# %%
img3 = img[10:100,10:100]
plt.imshow(img3)

# %% [markdown]
# 3. Tampilkan image baris ke 5-30, semua kolom, channel Green saja!

# %%
plt.imshow(img3[5:30], cmap='Greens')

# %% [markdown]
# 4. Buat 5 kotak berbagai ukuran dan warna yang berbeda dalam satu image.
# disarankan menggunakan bilangan acak/random!

# %%
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
cv.rectangle(img3,pt1=(50,75),pt2=(100,150),color=(255,255,255),thickness=10)
cv.rectangle(img3,pt1=(20,60),pt2=(40,120),color=(0,0,255),thickness=10)
cv.rectangle(img3,pt1=(100,30),pt2=(50,15),color=(255,0,0),thickness=10)
cv.rectangle(img3,pt1=(150,220),pt2=(75,110),color=(0,0,0),thickness=10)
cv.rectangle(img3,pt1=(100,9),pt2=(300,150),color=(0,255,0),thickness=10)
plt.imshow(img3)

# %% [markdown]
# 5. Tampilkan image dengan posisi terbalik!

# %%
img3 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)
fig =plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(img3)

# %% [markdown]
# 6. Buat rectangle dan circle pada bagian wajah dari image kitten!

# %%
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
cv.rectangle(img3,pt1=(450,400),pt2=(300,200),color=(0,255,0),thickness=5)
cv.circle(img3,center=(367,300),radius=40,color=(255,0,0),thickness=5)

plt.imshow(img3)

# %% [markdown]
# 7. Buat rectangle pada bagian sudut bawah kiri channel B pada color space RGB
# dari citra kitten01.jpg!

# %%
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
cv.rectangle(img3,pt1=(100,450),pt2=(0,1000),color=(0,255,0),thickness=5)
plt.imshow(img3)
